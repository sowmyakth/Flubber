# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=np.loadtxt('gr3_e.dat')

# %%
data[0]
# Out:
# array([ 0.07903019,  0.64476918,  0.02226133, ...,  0.16453192,
#         0.00148515, -0.3806453 ])

# %%
plt.plot(data[0])

# %%
plt.plot(data[1])

# %%
plt.plot((data[0]**2+data[1]**2)**0.5)
